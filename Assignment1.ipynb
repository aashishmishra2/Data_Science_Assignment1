# %%
# "Q1. Explain with an example each when to use a for loop and a while loop")
#Answer  

print("For Loop: to iterate values in the variable")
print("Output of Question 1")
a=[1,2,3]
for k in a:
    print(k)

print()
print("While Loop : to execute something till the condition stand True.")

i=1
while i < 3:
    print(i)
    i=i+1
    
#Q2. Write a python program to print the sum and product of the first 10 natural numbers using for and while loop.
#Answer :    
print()
print("Output of Question 2")
print("########### FOR LOOP ###########")
sum=0
for i in range(1,11):
    sum=i+sum
print("The Sum is", sum)
          
print("##########  WHILE LOOP  ###########")
sum=0
i=1
while i<=10:
    sum=i+sum
    i=i+1
print("The Sum is", sum)
          
#Q3. Create a python program to compute the electricity bill for a household.The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
#be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
#You are required to take the units of electricity consumed in a month from the user as input.
#Your program must pass this test case: when the unit of electricity consumed by the user in a month is
#310, the total electricity bill should be 2250.

#ANS : 
print()
print("Output of Question 3")
unit=int(input("Enter your Electricity unit"))
# unit<=100 = Rs. 4.5/unit
# 100<unit<=200 = Rs. 6/unit
# 200<unit<=300 = Rs. 10/unit
# 300 <unit     = Rs. 20/unit
#price_100 = 450
#price_200 = 600
#price_300 = 1000
#price_300_more = 20*unit
if unit <= 100:
         price_100= unit*4.5
         print("Your Charges are",price_100)
if unit > 100 and unit <=200: 
         price_200 = 450 + (unit - 100)*6
         print("Your Charges are",price_200)
if unit >200 and unit <=300:
         price_300 = 600+(unit - 200)*10
         print("your charges are",price_300)
if unit > 300:
         price_300_more = 450+600+1000+(unit-300)*20
         print("Your charges are",price_300_more)
      

    
print()
print("Output of Question 4")
         
#Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
#number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
#that list.
#Ans:

print("#################For Loop ###################")
print("List of Number between 1 to 100 whose cube is divisible by 4 and 5")
c=[]
for i in range(1,101):
    cube=i*i*i
    if cube%4==0 or cube%5==0:
        c.append(i)

print(c)


print("#################### While Loop ##########################")
print("List of Number between 1 to 100 whose cube is divisible by 4 and 5")
c=[]
i=1
while i<=100:
    cube = i*i*i
    if cube%4 == 0 or cube%5 ==0:
        c.append(i)
    i=i+1
print(c)

#Q5. Write a program to filter count vowels in the below-given string.

#string = "I want to become a data scientist"

#Ans : 
print()
print("Output of Question 5")
string ="I want to become a data scientist"
count=0
for i in string:
    if i == "a" or i == "A" or i == "e" or i == "E" or i == "i" or i == "I" or i == "o" or i == "O" or i == "u" or i == "U":
        count=count+1
print("Count of Vowels in the provided string is:", count)
# Out:
# For Loop: to iterate values in the variable
# Output of Question 1
# 1
# 2
# 3
#
# While Loop : to execute something till the condition stand True.
# 1
# 2
#
# Output of Question 2
# ########### FOR LOOP ###########
# The Sum is 55
# ##########  WHILE LOOP  ###########
# The Sum is 55
#
# Output of Question 3
# Enter your Electricity unit 310
# Your charges are 2250
#
# Output of Question 4
# #################For Loop ###################
# List of Number between 1 to 100 whose cube is divisible by 4 and 5
# [2, 4, 5, 6, 8, 10, 12, 14, 15, 16, 18, 20, 22, 24, 25, 26, 28, 30, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 52, 54, 55, 56, 58, 60, 62, 64, 65, 66, 68, 70, 72, 74, 75, 76, 78, 80, 82, 84, 85, 86, 88, 90, 92, 94, 95, 96, 98, 100]
# #################### While Loop ##########################
# List of Number between 1 to 100 whose cube is divisible by 4 and 5
# ...
